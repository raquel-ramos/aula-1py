# %%
 # !python --version
# Out:
# Python 3.11.7

# %%
import pandas as pd

print(pd)
print(pd.__version__)
# Out:
# <module 'pandas' from 'C:\\Users\\LABORATORIO\\anaconda3\\envs\\fema-si\\Lib\\site-packages\\pandas\\__init__.py'>
# 2.1.4

# %%
import urllib.request 

print(urllib.request)
print(urllib.request.__version__)
# Out:
# <module 'urllib.request' from 'C:\\Users\\LABORATORIO\\anaconda3\\envs\\fema-si\\Lib\\urllib\\request.py'>
# 3.11

# %%
import re

# %%
titanic_url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
print(titanic_url)
# Out:
# https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %%
urllib.request.urlretrieve(titanic_url, 'titanic.csv')
# Out:
# ('titanic.csv', <http.client.HTTPMessage at 0x1ff5bb0e250>)

# %%
#df = Pandas DataFrame
df = pd.read_csv('titanic.csv', sep=',', encoding = 'utf8')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# () = tupla = lista inutável
print(df.shape)
print(df.shape[0], 'linhas')
print(df.shape[1], 'colunas')
# Out:
# (891, 12)
# 891 linhas
# 12 colunas

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# dtypes = data types / 0 = object = string/texto
#Pandas Series = 2 colunas
list(df.dtypes)
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('O'),
#  dtype('O')]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
list(
    zip(
        df.columns.tolist(),
        map(lambda dtype: dtype.name, df.dtypes.tolist())
    )
)
# Out:
# [('PassengerId', 'int64'),
#  ('Survived', 'int64'),
#  ('Pclass', 'int64'),
#  ('Name', 'object'),
#  ('Sex', 'object'),
#  ('Age', 'float64'),
#  ('SibSp', 'int64'),
#  ('Parch', 'int64'),
#  ('Ticket', 'object'),
#  ('Fare', 'float64'),
#  ('Cabin', 'object'),
#  ('Embarked', 'object')]

# %%
df.select_dtypes(include =['int64'])
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['Age', 'Fare']].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_view = df[['Name', 'Age']].copy()
df_view
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df_view.head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
df_view.head(3)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0

# %%
df_view.iloc[3]
# Out:
# Name    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Age                                             35.0
# Name: 3, dtype: object

# %%
df_view[:8]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN
# 6                            McCarthy, Mr. Timothy J  54.0
# 7                     Palsson, Master. Gosta Leonard   2.0

# %%
df_view[-8:]
# Out:
#                                          Name   Age
# 883             Banfield, Mr. Frederick James  28.0
# 884                    Sutehall, Mr. Henry Jr  25.0
# 885      Rice, Mrs. William (Margaret Norton)  39.0
# 886                     Montvila, Rev. Juozas  27.0
# 887              Graham, Miss. Margaret Edith  19.0
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                     Behr, Mr. Karl Howell  26.0
# 890                       Dooley, Mr. Patrick  32.0
